# %%
import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (Input, Lambda, Conv2D, Conv2DTranspose, Dropout, MaxPooling2D,
                                     AveragePooling2D, UpSampling2D, DepthwiseConv2D, SeparableConv2D,
                                     GlobalAveragePooling2D, GlobalMaxPooling2D, Dense, Reshape, Multiply,
                                     Concatenate, Add, BatchNormalization, Activation, ReLU, LayerNormalization)
from tensorflow.keras.activations import gelu
tf.keras.backend.clear_session()
from keras.applications import EfficientNetV2M


def repeat_elem(tensor, rep):
    return tf.keras.layers.Lambda(lambda x, repnum: K.repeat_elements(x, repnum, axis=3),
                                  arguments={'repnum': rep})(tensor)

def ECA(x):
    k_size = 5
    squeeze = tf.reduce_mean(x, (2, 3))
    squeeze = tf.expand_dims(squeeze, axis=1)
    attn = tf.keras.layers.Conv1D(1, k_size, padding='same', use_bias=False)(squeeze)
    attn = tf.expand_dims(tf.transpose(attn, [0, 2, 1]), 3)
    attn = tf.math.sigmoid(attn)
    return x * attn

def spatial_attention(input_tensor):
    avg_pool = GlobalAveragePooling2D()(input_tensor)
    max_pool = GlobalMaxPooling2D()(input_tensor)
    concat = Concatenate()([avg_pool, max_pool])
    attention = Dense(1, activation='sigmoid')(concat)
    attention = Reshape((1, 1, -1))(attention)
    return Multiply()([input_tensor, attention])

def channel_shuffle(x, groups):
    shape = tf.shape(x)
    batch_size, height, width, channels = shape[0], shape[1], shape[2], shape[3]
    channels_per_group = channels // groups
    x = tf.reshape(x, [batch_size, height, width, groups, channels_per_group])
    x = tf.transpose(x, [0, 1, 2, 4, 3])
    return tf.reshape(x, [batch_size, height, width, channels])

def SEDNet(x, repetition, filters, strides, dilation, groups):
    for _ in range(repetition):
        x = BatchNormalization()(x)
        x = ReLU()(x)
        y = Conv2D(4 * filters, 1, strides=strides, padding="same")(x)
        y = Conv2D(filters, 3, activation='relu', padding="same", dilation_rate=dilation)(y)
        x = Concatenate()([y, x])
        x = channel_shuffle(x, groups)
    return x

def SAEF(filters, length, inp):
    shortcut = Conv2D(filters, (1, 1), padding='same', use_bias=False)(inp)
    shortcut = BatchNormalization()(shortcut)
    out1 = Conv2D(filters, (3, 3), padding='same')(inp)
    out1 = BatchNormalization()(out1)
    out1 = Activation('relu')(out1)
    out1 = spatial_attention(out1)
    out2 = Conv2D(filters, (5, 5), padding='same')(inp)
    out2 = BatchNormalization()(out2)
    out2 = Activation('relu')(out2)
    out2 = spatial_attention(out2)
    out = Add()([shortcut, out1, out2])
    out = Activation('relu')(out)
    return BatchNormalization()(out)


def EMSCA(x, filters):
    shape = x.shape
    y1 = AveragePooling2D(pool_size=(shape[1], shape[2]))(x)
    y1 = Conv2D(filters, (1, 1), padding="same")(y1)
    y1 = BatchNormalization()(y1)
    y1 = Activation("relu")(y1)
    y1 = UpSampling2D((shape[1], shape[2]), interpolation='bilinear')(y1)

    def branch(x, dilation):
        y = Conv2D(filters, (1, 1), padding="same")(x)
        y = DepthwiseConv2D((3, 3), dilation_rate=(dilation, dilation), padding="same")(y)
        y = Conv2D(filters, (1, 1), padding="same", use_bias=False)(y)
        y = BatchNormalization()(y)
        y = Activation("relu")(y)
        y = ECA(y)
        y = Conv2D(filters, (1, 1), padding="same")(y)
        return Add()([y, x])

    y2 = branch(x, 4)
    y3 = branch(x, 8)
    y4 = branch(x, 12)

    y = Concatenate()([y1, y2, y3, y4])
    y = DepthwiseConv2D((3, 3), padding="same")(y)
    y = Conv2D(filters, (1, 1), padding="same", use_bias=False)(y)
    y = BatchNormalization()(y)
    y = Activation("relu")(y)
    return y

def mscc_branch(x, kernel_size, filters=16):
    y = DepthwiseConv2D((kernel_size, 1), padding='same', activation='relu')(x)
    y = DepthwiseConv2D((1, kernel_size), padding='same', activation='relu')(y)
    y = Conv2D(filters, (1, 1), padding='same', activation='relu')(y)
    return y

def MSCC(input_tensor, filters=16):
    k_sizes = [11, 9, 7, 5]
    branches = [mscc_branch(input_tensor, k, filters) for k in k_sizes]
    return Concatenate()(branches)


def gating_signal(inputs, out_size):
    x = Conv2D(out_size, (1, 1), padding='same')(inputs)
    x = BatchNormalization()(x)
    return Activation('relu')(x)

def attention_block(x, gating, inter_shape):
    shape_x, shape_g = K.int_shape(x), K.int_shape(gating)
    theta_x = Conv2D(inter_shape, (2, 2), strides=(2, 2), padding='same')(x)
    phi_g = Conv2D(inter_shape, (1, 1), padding='same')(gating)
    upsample_g = Conv2DTranspose(inter_shape, (3, 3), strides=(theta_x.shape[1] // shape_g[1], theta_x.shape[2] // shape_g[2]), padding='same')(phi_g)
    concat_xg = Add()([upsample_g, theta_x])
    act_xg = Activation('relu')(concat_xg)
    psi = Conv2D(1, (1, 1), padding='same')(act_xg)
    sigmoid_xg = Activation('sigmoid')(psi)
    upsample_psi = UpSampling2D(size=(shape_x[1] // sigmoid_xg.shape[1], shape_x[2] // sigmoid_xg.shape[2]))(sigmoid_xg)
    upsample_psi = repeat_elem(upsample_psi, shape_x[3])
    y = Multiply()([upsample_psi, x])
    result = Conv2D(shape_x[3], (1, 1), padding='same')(y)
    return BatchNormalization()(result)


def SS_MLP(input_tensor, num_channels, shift_amount=5, dropout_rate=0.1):
    def shift_tensor(x, shift, axis):
        if shift > 0:
            if axis == 1:
                x = tf.pad(x, [[0, 0], [shift, 0], [0, 0], [0, 0]])
                x = x[:, :-shift, :, :]
            elif axis == 2:
                x = tf.pad(x, [[0, 0], [0, 0], [shift, 0], [0, 0]])
                x = x[:, :, :-shift, :]
        return x

    def apply_shifted_mlp(x, shift, axis):
        x_shifted = shift_tensor(x, shift, axis)
        x_shifted = DepthwiseConv2D(kernel_size=(3, 3), padding='same')(x_shifted)
        x_shifted = Activation(gelu)(x_shifted)
        x_shifted = Dropout(dropout_rate)(x_shifted)
        return shift_tensor(x_shifted, -shift, axis)

    x = LayerNormalization()(input_tensor)
    x_h = apply_shifted_mlp(x, shift_amount, axis=1)
    x_w = apply_shifted_mlp(x, shift_amount, axis=2)
    return Add()([x, x_h, x_w])

def ERC(input, num_filters, dilation_rate=1):
    x = Conv2D(num_filters, 3, padding="same", dilation_rate=dilation_rate)(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    x = Conv2D(num_filters, 3, padding="same", dilation_rate=dilation_rate)(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)
    shortcut = Conv2D(num_filters, 1, padding='same')(input)
    shortcut = BatchNormalization()(shortcut)
    x = Concatenate()([shortcut, x])
    x = Activation("relu")(x)
    return ECA(x)

def cross_attention_module(high_level_features, low_level_features, filters):
    high = Conv2D(filters, (1, 1), padding='same', activation='relu')(high_level_features)
    high = Conv2D(filters, (3, 3), padding='same', activation='relu')(high)
    high = Lambda(lambda t: tf.image.resize(t[0], tf.shape(t[1])[1:3], method='bilinear'))([high, low_level_features])
    low = Conv2D(filters, (1, 1), padding='same', activation='relu')(low_level_features)
    low = Conv2D(filters, (3, 3), padding='same', activation='relu')(low)
    fused = ReLU()(Add()([high, low]))
    attn = GlobalAveragePooling2D()(fused)
    attn = Reshape((1, 1, filters))(attn)
    attn = Conv2D(filters, (1, 1), activation='sigmoid')(attn)
    return Multiply()([fused, attn])

def decoder_block(input, skip, filters, dilation_rate=1):
    cross = cross_attention_module(input, skip, filters)
    gate = gating_signal(input, filters)
    attn = attention_block(cross, gate, filters)
    x = UpSampling2D((2, 2), interpolation="bilinear")(input)
    x = Concatenate()([x, attn])
    x = SS_MLP(x, filters, shift_amount=5, dropout_rate=0.1)
    return ERC(x, filters, dilation_rate=dilation_rate)

# --- Model Architecture ---
inputs = Input((256, 256, 3))
s = Lambda(lambda x: x / 255)(inputs)
irnet = EfficientNetV2M(include_top=False, weights="imagenet", input_tensor=inputs)

# Backbone outputs
s = irnet.get_layer("input_1").output
s2 = irnet.get_layer("block1c_project_activation").output
s3 = irnet.get_layer("block2c_expand_activation").output
s4 = irnet.get_layer("block3c_expand_activation").output

print("Backbone s shape:", s.shape)
print("Backbone s2 shape:", s2.shape)
print("Backbone s3 shape:", s3.shape)
print("Backbone s4 shape:", s4.shape)

mscc_out = MSCC(s)
print("After MSCC:", mscc_out.shape)

c1 = SEDNet(mscc_out, repetition=2, filters=16, strides=1, dilation=1, groups=4)
c1 = Concatenate()([c1, s])
print("After Encoder Stage 1 (Concatenated with s):", c1.shape)
p1 = MaxPooling2D((2, 2))(c1)
c1 = SAEF(16, 4, c1)

c2 = SEDNet(ERC(p1, 32), 2, 32, 1, 2, 4)
c2 = Concatenate()([c2, s2])
print("After Encoder Stage 2:", c2.shape)
p2 = MaxPooling2D((2, 2))(c2)
c2 = SAEF(32, 3, c2)

c3 = SEDNet(ERC(p2, 64), 2, 64, 1, 3, 4)
c3 = Concatenate()([c3, s3])
print("After Encoder Stage 3:", c3.shape)
p3 = MaxPooling2D((2, 2))(c3)
c3 = SAEF(64, 2, c3)

c4 = SEDNet(ERC(p3, 128), 2, 128, 1, 4, 4)
c4 = Concatenate()([c4, s4])
print("After Encoder Stage 4:", c4.shape)
p4 = MaxPooling2D((2, 2))(c4)
c4 = SAEF(128, 1, c4)

mlp_out = SS_MLP(c4, 128, shift_amount=5, dropout_rate=0.1)
mlp_out = MaxPooling2D(pool_size=(2, 2))(mlp_out)
mlp_out = Conv2D(256, (1, 1), padding='same', activation='relu')(mlp_out)

conv_out = Conv2D(256, (3, 3), activation='relu', padding='same')(
               Dropout(0.2)(
                   Conv2D(256, (3, 3), activation='relu', padding='same')(p4)))

fused_bottleneck = Add()([mlp_out, conv_out])
print("After Bottleneck Fusion:", fused_bottleneck.shape)

c5 = EMSCA(fused_bottleneck, 256)
print("After EMSCA:", c5.shape)

d1 = decoder_block(c5, c4, 256, 1)
print("After Decoder Stage 1:", d1.shape)
d2 = decoder_block(d1, c3, 128, 2)
print("After Decoder Stage 2:", d2.shape)
d3 = decoder_block(d2, c2, 128, 4)
print("After Decoder Stage 3:", d3.shape)
d4 = decoder_block(d3, c1, 64, 8)
print("After Decoder Stage 4:", d4.shape)

outputs = Conv2D(1, (1, 1), activation='sigmoid')(d4)
print("Final Output:", outputs.shape)

model = Model(inputs=inputs, outputs=outputs)
model._name = "MSAC-Net"

model.summary()
# Out:
# Backbone s shape: (None, 256, 256, 3)
# Backbone s2 shape: (None, 128, 128, 24)
# Backbone s3 shape: (None, 64, 64, 192)
# Backbone s4 shape: (None, 32, 32, 320)
# After MSCC: (None, 256, 256, 64)
# After Encoder Stage 1 (Concatenated with s): (None, 256, 256, 99)
# After Encoder Stage 2: (None, 128, 128, 152)
# After Encoder Stage 3: (None, 64, 64, 448)
# After Encoder Stage 4: (None, 32, 32, 832)
# After Bottleneck Fusion: (None, 16, 16, 256)
# After EMSCA: (None, 16, 16, 256)
# After Decoder Stage 1: (None, 32, 32, 512)
# After Decoder Stage 2: (None, 64, 64, 256)
# After Decoder Stage 3: (None, 128, 128, 256)
# After Decoder Stage 4: (None, 256, 256, 128)
# Final Output: (None, 256, 256, 1)
# Model: "MSAC-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  depthwise_conv2d (DepthwiseCon  (None, 256, 256, 3)  36         ['input_1[0][0]']
#  v2D)
#
#  depthwise_conv2d_2 (DepthwiseC  (None, 256, 256, 3)  30         ['input_1[0][0]']
#  onv2D)
#
#  depthwise_conv2d_4 (DepthwiseC  (None, 256, 256, 3)  24         ['input_1[0][0]']
#  onv2D)
#
#  depthwise_conv2d_6 (DepthwiseC  (None, 256, 256, 3)  18         ['input_1[0][0]']
#  onv2D)
#
#  depthwise_conv2d_1 (DepthwiseC  (None, 256, 256, 3)  36         ['depthwise_conv2d[0][0]']
#  onv2D)
#
#  depthwise_conv2d_3 (DepthwiseC  (None, 256, 256, 3)  30         ['depthwise_conv2d_2[0][0]']
#  onv2D)
#
#  depthwise_conv2d_5 (DepthwiseC  (None, 256, 256, 3)  24         ['depthwise_conv2d_4[0][0]']
#  onv2D)
#
#  depthwise_conv2d_7 (DepthwiseC  (None, 256, 256, 3)  18         ['depthwise_conv2d_6[0][0]']
#  onv2D)
#
#  conv2d (Conv2D)                (None, 256, 256, 16  64          ['depthwise_conv2d_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 16  64          ['depthwise_conv2d_3[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 16  64          ['depthwise_conv2d_5[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 16  64          ['depthwise_conv2d_7[0][0]']
#                                 )
#
#  concatenate (Concatenate)      (None, 256, 256, 64  0           ['conv2d[0][0]',
#                                 )                                 'conv2d_1[0][0]',
#                                                                   'conv2d_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization (BatchNorm  (None, 256, 256, 64  256        ['concatenate[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_4 (Conv2D)              (None, 256, 256, 64  4160        ['re_lu[0][0]']
#                                 )
#
#  conv2d_5 (Conv2D)              (None, 256, 256, 16  9232        ['conv2d_4[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 256, 256, 80  0           ['conv2d_5[0][0]',
#                                 )                                 're_lu[0][0]']
#
#  tf.compat.v1.shape (TFOpLambda  (4,)                0           ['concatenate_1[0][0]']
#  )
#
#  tf.__operators__.getitem_3 (Sl  ()                  0           ['tf.compat.v1.shape[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem (Slic  ()                  0           ['tf.compat.v1.shape[0][0]']
#  ingOpLambda)
#
#  tf.__operators__.getitem_1 (Sl  ()                  0           ['tf.compat.v1.shape[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_2 (Sl  ()                  0           ['tf.compat.v1.shape[0][0]']
#  icingOpLambda)
#
#  tf.compat.v1.floor_div (TFOpLa  ()                  0           ['tf.__operators__.getitem_3[0][0
#  mbda)                                                           ]']
#
#  tf.reshape (TFOpLambda)        (None, 256, 256, 4,  0           ['concatenate_1[0][0]',
#                                  20)                              'tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]',
#                                                                   'tf.compat.v1.floor_div[0][0]']
#
#  tf.compat.v1.transpose (TFOpLa  (None, 256, 256, 20  0          ['tf.reshape[0][0]']
#  mbda)                          , 4)
#
#  tf.reshape_1 (TFOpLambda)      (None, 256, 256, 80  0           ['tf.compat.v1.transpose[0][0]',
#                                 )                                 'tf.__operators__.getitem[0][0]'
#                                                                  , 'tf.__operators__.getitem_1[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_2[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_3[0][0
#                                                                  ]']
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 80  320        ['tf.reshape_1[0][0]']
#  rmalization)                   )
#
#  re_lu_1 (ReLU)                 (None, 256, 256, 80  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_6 (Conv2D)              (None, 256, 256, 64  5184        ['re_lu_1[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 256, 256, 16  9232        ['conv2d_6[0][0]']
#                                 )
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 96  0           ['conv2d_7[0][0]',
#                                 )                                 're_lu_1[0][0]']
#
#  tf.compat.v1.shape_1 (TFOpLamb  (4,)                0           ['concatenate_2[0][0]']
#  da)
#
#  tf.__operators__.getitem_7 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_4 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_5 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_6 (Sl  ()                  0           ['tf.compat.v1.shape_1[0][0]']
#  icingOpLambda)
#
#  tf.compat.v1.floor_div_1 (TFOp  ()                  0           ['tf.__operators__.getitem_7[0][0
#  Lambda)                                                         ]']
#
#  tf.reshape_2 (TFOpLambda)      (None, 256, 256, 4,  0           ['concatenate_2[0][0]',
#                                  24)                              'tf.__operators__.getitem_4[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_6[0][0
#                                                                  ]',
#                                                                   'tf.compat.v1.floor_div_1[0][0]'
#                                                                  ]
#
#  tf.compat.v1.transpose_1 (TFOp  (None, 256, 256, 24  0          ['tf.reshape_2[0][0]']
#  Lambda)                        , 4)
#
#  tf.reshape_3 (TFOpLambda)      (None, 256, 256, 96  0           ['tf.compat.v1.transpose_1[0][0]'
#                                 )                                , 'tf.__operators__.getitem_4[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_5[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_6[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_7[0][0
#                                                                  ]']
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 99  0           ['tf.reshape_3[0][0]',
#                                 )                                 'input_1[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 99  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 32  28544       ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 32  128        ['conv2d_11[0][0]']
#  rmalization)                   )
#
#  activation_3 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 32  9248        ['activation_3[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 128, 128, 32  3200        ['max_pooling2d[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 32  128        ['conv2d_12[0][0]']
#  rmalization)                   )
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 32  128        ['conv2d_13[0][0]']
#  rmalization)                   )
#
#  activation_4 (Activation)      (None, 128, 128, 32  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 64  0           ['batch_normalization_8[0][0]',
#                                 )                                 'activation_4[0][0]']
#
#  activation_5 (Activation)      (None, 128, 128, 64  0           ['concatenate_6[0][0]']
#                                 )
#
#  tf.math.reduce_mean (TFOpLambd  (None, 128)         0           ['activation_5[0][0]']
#  a)
#
#  tf.expand_dims (TFOpLambda)    (None, 1, 128)       0           ['tf.math.reduce_mean[0][0]']
#
#  conv1d (Conv1D)                (None, 1, 1)         640         ['tf.expand_dims[0][0]']
#
#  tf.compat.v1.transpose_2 (TFOp  (None, 1, 1)        0           ['conv1d[0][0]']
#  Lambda)
#
#  tf.expand_dims_1 (TFOpLambda)  (None, 1, 1, 1)      0           ['tf.compat.v1.transpose_2[0][0]'
#                                                                  ]
#
#  tf.math.sigmoid (TFOpLambda)   (None, 1, 1, 1)      0           ['tf.expand_dims_1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 128, 128, 64  0           ['activation_5[0][0]',
#                                 )                                 'tf.math.sigmoid[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 64  256        ['tf.math.multiply[0][0]']
#  rmalization)                   )
#
#  re_lu_2 (ReLU)                 (None, 128, 128, 64  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  8320        ['re_lu_2[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 32  36896       ['conv2d_14[0][0]']
#                                 )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 96  0           ['conv2d_15[0][0]',
#                                 )                                 're_lu_2[0][0]']
#
#  tf.compat.v1.shape_2 (TFOpLamb  (4,)                0           ['concatenate_7[0][0]']
#  da)
#
#  tf.__operators__.getitem_11 (S  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  licingOpLambda)
#
#  rescaling (Rescaling)          (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  tf.__operators__.getitem_8 (Sl  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_9 (Sl  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  icingOpLambda)
#
#  tf.__operators__.getitem_10 (S  ()                  0           ['tf.compat.v1.shape_2[0][0]']
#  licingOpLambda)
#
#  tf.compat.v1.floor_div_2 (TFOp  ()                  0           ['tf.__operators__.getitem_11[0][
#  Lambda)                                                         0]']
#
#  stem_conv (Conv2D)             (None, 128, 128, 24  648         ['rescaling[0][0]']
#                                 )
#
#  tf.reshape_4 (TFOpLambda)      (None, 128, 128, 4,  0           ['concatenate_7[0][0]',
#                                  24)                              'tf.__operators__.getitem_8[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_9[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_10[0][
#                                                                  0]',
#                                                                   'tf.compat.v1.floor_div_2[0][0]'
#                                                                  ]
#
#  stem_bn (BatchNormalization)   (None, 128, 128, 24  96          ['stem_conv[0][0]']
#                                 )
#
#  tf.compat.v1.transpose_3 (TFOp  (None, 128, 128, 24  0          ['tf.reshape_4[0][0]']
#  Lambda)                        , 4)
#
#  stem_activation (Activation)   (None, 128, 128, 24  0           ['stem_bn[0][0]']
#                                 )
#
#  tf.reshape_5 (TFOpLambda)      (None, 128, 128, 96  0           ['tf.compat.v1.transpose_3[0][0]'
#                                 )                                , 'tf.__operators__.getitem_8[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_9[0][0
#                                                                  ]',
#                                                                   'tf.__operators__.getitem_10[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_11[0][
#                                                                  0]']
#
#  block1a_project_conv (Conv2D)  (None, 128, 128, 24  5184        ['stem_activation[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 128, 128, 96  384        ['tf.reshape_5[0][0]']
#  ormalization)                  )
#
#  block1a_project_bn (BatchNorma  (None, 128, 128, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  re_lu_3 (ReLU)                 (None, 128, 128, 96  0           ['batch_normalization_10[0][0]']
#                                 )
#
#  block1a_project_activation (Ac  (None, 128, 128, 24  0          ['block1a_project_bn[0][0]']
#  tivation)                      )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 12  12416       ['re_lu_3[0][0]']
#                                 8)
#
#  block1a_add (Add)              (None, 128, 128, 24  0           ['block1a_project_activation[0][0
#                                 )                                ]',
#                                                                   'stem_activation[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  36896       ['conv2d_16[0][0]']
#                                 )
#
#  block1b_project_conv (Conv2D)  (None, 128, 128, 24  5184        ['block1a_add[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_17[0][0]',
#                                 8)                                're_lu_3[0][0]']
#
#  block1b_project_bn (BatchNorma  (None, 128, 128, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  tf.compat.v1.shape_3 (TFOpLamb  (4,)                0           ['concatenate_8[0][0]']
#  da)
#
#  block1b_project_activation (Ac  (None, 128, 128, 24  0          ['block1b_project_bn[0][0]']
#  tivation)                      )
#
#  tf.__operators__.getitem_15 (S  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  licingOpLambda)
#
#  block1b_drop (Dropout)         (None, 128, 128, 24  0           ['block1b_project_activation[0][0
#                                 )                                ]']
#
#  tf.__operators__.getitem_12 (S  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_13 (S  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_14 (S  ()                  0           ['tf.compat.v1.shape_3[0][0]']
#  licingOpLambda)
#
#  tf.compat.v1.floor_div_3 (TFOp  ()                  0           ['tf.__operators__.getitem_15[0][
#  Lambda)                                                         0]']
#
#  block1b_add (Add)              (None, 128, 128, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_add[0][0]']
#
#  tf.reshape_6 (TFOpLambda)      (None, 128, 128, 4,  0           ['concatenate_8[0][0]',
#                                  32)                              'tf.__operators__.getitem_12[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_14[0][
#                                                                  0]',
#                                                                   'tf.compat.v1.floor_div_3[0][0]'
#                                                                  ]
#
#  block1c_project_conv (Conv2D)  (None, 128, 128, 24  5184        ['block1b_add[0][0]']
#                                 )
#
#  tf.compat.v1.transpose_4 (TFOp  (None, 128, 128, 32  0          ['tf.reshape_6[0][0]']
#  Lambda)                        , 4)
#
#  block1c_project_bn (BatchNorma  (None, 128, 128, 24  96         ['block1c_project_conv[0][0]']
#  lization)                      )
#
#  tf.reshape_7 (TFOpLambda)      (None, 128, 128, 12  0           ['tf.compat.v1.transpose_4[0][0]'
#                                 8)                               , 'tf.__operators__.getitem_12[0]
#                                                                  [0]',
#                                                                   'tf.__operators__.getitem_13[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_14[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_15[0][
#                                                                  0]']
#
#  block1c_project_activation (Ac  (None, 128, 128, 24  0          ['block1c_project_bn[0][0]']
#  tivation)                      )
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 15  0           ['tf.reshape_7[0][0]',
#                                 2)                                'block1c_project_activation[0][0
#                                                                  ]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 152)  0          ['concatenate_9[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 64, 64, 64)   87616       ['max_pooling2d_1[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 64)  256         ['conv2d_21[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 64, 64, 64)   0           ['batch_normalization_15[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 64, 64, 64)   36928       ['activation_9[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 64)   9792        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['conv2d_22[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 64, 64, 64)  256         ['conv2d_23[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 64, 64, 64)   0           ['batch_normalization_16[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 64, 64, 128)  0           ['batch_normalization_17[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 64, 64, 128)  0           ['concatenate_12[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 64)          0           ['activation_11[0][0]']
#  bda)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 1, 64)        0           ['tf.math.reduce_mean_1[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1, 1)         320         ['tf.expand_dims_2[0][0]']
#
#  tf.compat.v1.transpose_5 (TFOp  (None, 1, 1)        0           ['conv1d_1[0][0]']
#  Lambda)
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 1, 1, 1)      0           ['tf.compat.v1.transpose_5[0][0]'
#                                                                  ]
#
#  tf.math.sigmoid_1 (TFOpLambda)  (None, 1, 1, 1)     0           ['tf.expand_dims_3[0][0]']
#
#  tf.math.multiply_1 (TFOpLambda  (None, 64, 64, 128)  0          ['activation_11[0][0]',
#  )                                                                'tf.math.sigmoid_1[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 64, 64, 128)  512        ['tf.math.multiply_1[0][0]']
#  ormalization)
#
#  re_lu_4 (ReLU)                 (None, 64, 64, 128)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 256)  33024       ['re_lu_4[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 64, 64, 64)   147520      ['conv2d_24[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 192)  0           ['conv2d_25[0][0]',
#                                                                   're_lu_4[0][0]']
#
#  tf.compat.v1.shape_4 (TFOpLamb  (4,)                0           ['concatenate_13[0][0]']
#  da)
#
#  block1c_drop (Dropout)         (None, 128, 128, 24  0           ['block1c_project_activation[0][0
#                                 )                                ]']
#
#  tf.__operators__.getitem_19 (S  ()                  0           ['tf.compat.v1.shape_4[0][0]']
#  licingOpLambda)
#
#  block1c_add (Add)              (None, 128, 128, 24  0           ['block1c_drop[0][0]',
#                                 )                                 'block1b_add[0][0]']
#
#  tf.__operators__.getitem_16 (S  ()                  0           ['tf.compat.v1.shape_4[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_17 (S  ()                  0           ['tf.compat.v1.shape_4[0][0]']
#  licingOpLambda)
#
#  tf.__operators__.getitem_18 (S  ()                  0           ['tf.compat.v1.shape_4[0][0]']
#  licingOpLambda)
#
#  tf.compat.v1.floor_div_4 (TFOp  ()                  0           ['tf.__operators__.getitem_19[0][
#  Lambda)                                                         0]']
#
#  block2a_expand_conv (Conv2D)   (None, 64, 64, 96)   20736       ['block1c_add[0][0]']
#
#  tf.reshape_8 (TFOpLambda)      (None, 64, 64, 4, 4  0           ['concatenate_13[0][0]',
#                                 8)                                'tf.__operators__.getitem_16[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_17[0][
#                                                                  0]',
#                                                                   'tf.__operators__.getitem_18[0][
#                                                                  0]',
#                                                                   'tf.compat.v1.floor_div_4[0][0]'
#                                                                  ]
#
#  block2a_expand_bn (BatchNormal  (None, 64, 64, 96)  384         ['block2a_expand_conv[0][0]']
#  ization)
#
#  tf.compat.v1.transpose_6 (TFOp  (None, 64, 64, 48,   0          ['tf.reshape_8[0][0]']
#  Lambda)                        4)
#
#  block2a_expand_activation (Act  (None, 64, 64, 96)  0           ['block2a_expand_bn[0][0]']
#  ivation)
#
#  tf.reshape_9 (TFOpLambda)      (None, 64, 64, 192)  0           ['tf.compat.v1.transpose_6[0][0]'
#                                                                  , 'tf.__operators__.getitem_16[0]
# ...
#  lambda_7 (Lambda)              (None, 256, 256, 64  0           ['conv2d_95[0][0]',
#                                 )                                 'batch_normalization_5[0][0]']
#
#  conv2d_97 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_96[0][0]']
#                                 )
#
#  add_18 (Add)                   (None, 256, 256, 64  0           ['lambda_7[0][0]',
#                                 )                                 'conv2d_97[0][0]']
#
#  re_lu_11 (ReLU)                (None, 256, 256, 64  0           ['add_18[0][0]']
#                                 )
#
#  conv2d_99 (Conv2D)             (None, 128, 128, 64  16448       ['tf.math.multiply_8[0][0]']
#                                 )
#
#  global_average_pooling2d_11 (G  (None, 64)          0           ['re_lu_11[0][0]']
#  lobalAveragePooling2D)
#
#  batch_normalization_53 (BatchN  (None, 128, 128, 64  256        ['conv2d_99[0][0]']
#  ormalization)                  )
#
#  reshape_11 (Reshape)           (None, 1, 1, 64)     0           ['global_average_pooling2d_11[0][
#                                                                  0]']
#
#  activation_52 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_53[0][0]']
#                                 )
#
#  conv2d_98 (Conv2D)             (None, 1, 1, 64)     4160        ['reshape_11[0][0]']
#
#  conv2d_101 (Conv2D)            (None, 128, 128, 64  4160        ['activation_52[0][0]']
#                                 )
#
#  multiply_14 (Multiply)         (None, 256, 256, 64  0           ['re_lu_11[0][0]',
#                                 )                                 'conv2d_98[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  36928      ['conv2d_101[0][0]']
#  spose)                         )
#
#  conv2d_100 (Conv2D)            (None, 128, 128, 64  16448       ['multiply_14[0][0]']
#                                 )
#
#  add_19 (Add)                   (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_100[0][0]']
#
#  activation_53 (Activation)     (None, 128, 128, 64  0           ['add_19[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 128, 128, 1)  65          ['activation_53[0][0]']
#
#  activation_54 (Activation)     (None, 128, 128, 1)  0           ['conv2d_102[0][0]']
#
#  up_sampling2d_7 (UpSampling2D)  (None, 256, 256, 1)  0          ['activation_54[0][0]']
#
#  lambda_8 (Lambda)              (None, 256, 256, 64  0           ['up_sampling2d_7[0][0]']
#                                 )
#
#  multiply_15 (Multiply)         (None, 256, 256, 64  0           ['lambda_8[0][0]',
#                                 )                                 'multiply_14[0][0]']
#
#  conv2d_103 (Conv2D)            (None, 256, 256, 64  4160        ['multiply_15[0][0]']
#                                 )
#
#  up_sampling2d_8 (UpSampling2D)  (None, 256, 256, 25  0          ['tf.math.multiply_8[0][0]']
#                                 6)
#
#  batch_normalization_54 (BatchN  (None, 256, 256, 64  256        ['conv2d_103[0][0]']
#  ormalization)                  )
#
#  concatenate_31 (Concatenate)   (None, 256, 256, 32  0           ['up_sampling2d_8[0][0]',
#                                 0)                                'batch_normalization_54[0][0]']
#
#  layer_normalization_4 (LayerNo  (None, 256, 256, 32  640        ['concatenate_31[0][0]']
#  rmalization)                   0)
#
#  tf.compat.v1.pad_8 (TFOpLambda  (None, 261, 256, 32  0          ['layer_normalization_4[0][0]']
#  )                              0)
#
#  tf.compat.v1.pad_9 (TFOpLambda  (None, 256, 261, 32  0          ['layer_normalization_4[0][0]']
#  )                              0)
#
#  tf.__operators__.getitem_40 (S  (None, 256, 256, 32  0          ['tf.compat.v1.pad_8[0][0]']
#  licingOpLambda)                0)
#
#  tf.__operators__.getitem_41 (S  (None, 256, 256, 32  0          ['tf.compat.v1.pad_9[0][0]']
#  licingOpLambda)                0)
#
#  depthwise_conv2d_20 (Depthwise  (None, 256, 256, 32  3200       ['tf.__operators__.getitem_40[0][
#  Conv2D)                        0)                               0]']
#
#  depthwise_conv2d_21 (Depthwise  (None, 256, 256, 32  3200       ['tf.__operators__.getitem_41[0][
#  Conv2D)                        0)                               0]']
#
#  activation_55 (Activation)     (None, 256, 256, 32  0           ['depthwise_conv2d_20[0][0]']
#                                 0)
#
#  activation_56 (Activation)     (None, 256, 256, 32  0           ['depthwise_conv2d_21[0][0]']
#                                 0)
#
#  dropout_9 (Dropout)            (None, 256, 256, 32  0           ['activation_55[0][0]']
#                                 0)
#
#  dropout_10 (Dropout)           (None, 256, 256, 32  0           ['activation_56[0][0]']
#                                 0)
#
#  add_20 (Add)                   (None, 256, 256, 32  0           ['layer_normalization_4[0][0]',
#                                 0)                                'dropout_9[0][0]',
#                                                                   'dropout_10[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 256, 256, 64  184384      ['add_20[0][0]']
#                                 )
#
#  batch_normalization_55 (BatchN  (None, 256, 256, 64  256        ['conv2d_104[0][0]']
#  ormalization)                  )
#
#  activation_57 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_55[0][0]']
#                                 )
#
#  conv2d_105 (Conv2D)            (None, 256, 256, 64  36928       ['activation_57[0][0]']
#                                 )
#
#  conv2d_106 (Conv2D)            (None, 256, 256, 64  20544       ['add_20[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 256, 256, 64  256        ['conv2d_105[0][0]']
#  ormalization)                  )
#
#  batch_normalization_57 (BatchN  (None, 256, 256, 64  256        ['conv2d_106[0][0]']
#  ormalization)                  )
#
#  activation_58 (Activation)     (None, 256, 256, 64  0           ['batch_normalization_56[0][0]']
#                                 )
#
#  concatenate_32 (Concatenate)   (None, 256, 256, 12  0           ['batch_normalization_57[0][0]',
#                                 8)                                'activation_58[0][0]']
#
#  activation_59 (Activation)     (None, 256, 256, 12  0           ['concatenate_32[0][0]']
#                                 8)
#
#  tf.math.reduce_mean_9 (TFOpLam  (None, 256)         0           ['activation_59[0][0]']
#  bda)
#
#  tf.expand_dims_18 (TFOpLambda)  (None, 1, 256)      0           ['tf.math.reduce_mean_9[0][0]']
#
#  conv1d_9 (Conv1D)              (None, 1, 1)         1280        ['tf.expand_dims_18[0][0]']
#
#  tf.compat.v1.transpose_17 (TFO  (None, 1, 1)        0           ['conv1d_9[0][0]']
#  pLambda)
#
#  tf.expand_dims_19 (TFOpLambda)  (None, 1, 1, 1)     0           ['tf.compat.v1.transpose_17[0][0]
#                                                                  ']
#
#  tf.math.sigmoid_9 (TFOpLambda)  (None, 1, 1, 1)     0           ['tf.expand_dims_19[0][0]']
#
#  tf.math.multiply_9 (TFOpLambda  (None, 256, 256, 12  0          ['activation_59[0][0]',
#  )                              8)                                'tf.math.sigmoid_9[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 256, 256, 1)  129         ['tf.math.multiply_9[0][0]']
#
# ==================================================================================================
# Total params: 20,064,461
# Trainable params: 20,045,965
# Non-trainable params: 18,496
# __________________________________________________________________________________________________
